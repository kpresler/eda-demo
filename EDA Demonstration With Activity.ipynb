# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read in our dataframe, and print out a few rows & columns
df = pd.read_excel("gm.xlsx")
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB
# country      0
# continent    0
# year         0
# lifeExp      0
# pop          0
# gdpPercap    0
# dtype: int64

# %%
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap
# count  1704.00000  1704.000000  1.704000e+03    1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081
# std      17.26533    12.917107  1.061579e+08    9857.454543
# min    1952.00000    23.599000  6.001100e+04     241.165876
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309
# 50%    1979.50000    60.712500  7.023596e+06    3531.846988
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346
# max    2007.00000    82.603000  1.318683e+09  113523.132900

# %%
df.plot.scatter(x="gdpPercap",y="lifeExp",c="none", edgecolors='r')
# Out:
# <Axes: xlabel='gdpPercap', ylabel='lifeExp'>

# %%
df[df["gdpPercap"] > 50000]
# Out:
#     country continent  year  lifeExp      pop     gdpPercap
# 852  Kuwait      Asia  1952   55.565   160000  108382.35290
# 853  Kuwait      Asia  1957   58.033   212846  113523.13290
# 854  Kuwait      Asia  1962   60.470   358266   95458.11176
# 855  Kuwait      Asia  1967   64.624   575003   80894.88326
# 856  Kuwait      Asia  1972   67.712   841934  109347.86700
# 857  Kuwait      Asia  1977   69.343  1140357   59265.47714

# %%
df[df["country"] == "Kuwait"].plot.scatter(x="year", y="gdpPercap")
# Out:
# <Axes: xlabel='year', ylabel='gdpPercap'>

# %%
gdp = df.pivot(index="country", columns="year", values="gdpPercap")
gdp
# Out:
# year                       1952         1957         1962         1967  \
# country
# Afghanistan          779.445314   820.853030   853.100710   836.197138
# Albania             1601.056136  1942.284244  2312.888958  2760.196931
# Algeria             2449.008185  3013.976023  2550.816880  3246.991771
# Angola              3520.610273  3827.940465  4269.276742  5522.776375
# Argentina           5911.315053  6856.856212  7133.166023  8052.953021
# ...                         ...          ...          ...          ...
# Vietnam              605.066492   676.285448   772.049160   637.123289
# West Bank and Gaza  1515.592329  1827.067742  2198.956312  2649.715007
# Yemen, Rep.          781.717576   804.830455   825.623201   862.442146
# Zambia              1147.388831  1311.956766  1452.725766  1777.077318
# Zimbabwe             406.884115   518.764268   527.272182   569.795071
#
# year                       1972          1977         1982         1987  \
# country
# ...

# %%
gdp_loss = gdp[gdp[1952] > gdp[2007]]
gdp_loss
# Out:
# year                               1952           1957          1962  \
# country
# Central African Republic    1071.310713    1190.844328   1193.068753
# Comoros                     1102.990936    1211.148548   1406.648278
# Congo, Dem. Rep.             780.542326     905.860230    896.314634
# Djibouti                    2669.529475    2864.969076   3020.989263
# Haiti                       1840.366939    1726.887882   1796.589032
# Kuwait                    108382.352900  113523.132900  95458.111760
# Liberia                      575.572996     620.969990    634.195163
# Madagascar                  1443.011715    1589.202750   1643.387110
# Nicaragua                   3112.363948    3457.415947   3634.364406
# Niger                        761.879376     835.523402    997.766113
# Sierra Leone                 879.787736    1004.484437   1116.639877
# Somalia                     1135.749842    1258.147413   1369.488336
#
# ...

# %%
decreased = gdp[gdp[1952] >= gdp[2007]]
decreased_country_names = list(decreased.index)
decreased_country_names
# Out:
# ['Central African Republic',
#  'Comoros',
#  'Congo, Dem. Rep.',
#  'Djibouti',
#  'Haiti',
#  'Kuwait',
#  'Liberia',
#  'Madagascar',
#  'Nicaragua',
#  'Niger',
#  'Sierra Leone',
#  'Somalia']

# %%
df[df["country"].isin(decreased_country_names)].plot.scatter(x="year", y="gdpPercap")
# Out:
# <Axes: xlabel='year', ylabel='gdpPercap'>

# %%
decreased_country_names.remove("Kuwait")
df[df["country"].isin(decreased_country_names)].plot.scatter(x="year", y="gdpPercap")
# Out:
# <Axes: xlabel='year', ylabel='gdpPercap'>

# %%
decreased_gdp_df = df[df["country"].isin(decreased_country_names)]

# %%
from mlxtend.plotting import category_scatter
fig = category_scatter(x='year', y='gdpPercap', label_col='country', 
                       data=decreased_gdp_df, legend_loc=False)

# %%
fig = category_scatter(x='year', y='gdpPercap', label_col='country', 
                       data=decreased_gdp_df, legend_loc=False)
fig.legend(bbox_to_anchor=(1.04, 1), loc="upper left")

# %% [markdown]
# # Scratch Space / Hints for Activities Here

# %% [markdown]
# ## Task 1: Life Expectancy Loss

# %%
# Your code for answering Task 1 can go here

# %% [markdown]
# Want a *Hint* on how to proceed?  Click into this cell, remove the `~` from below, and then hit Shift + Enter to re-render
#
#
# ~This task will be much easier if we pivot the data table, so that we can more readily compare results from each country in 2007 to the same country in 1952.  Alternatively, you can use a loop across all countries and generate a new DataFrame~

# %% [markdown]
# ## Task 2: GDP Growth

# %%
# Your code for answering Task 2 can go here

# %% [markdown]
# Want a *Hint* on how to proceed?  Click into this cell, remove the `~` from below, and then hit Shift + Enter to re-render
#
#
# ~We can look at GDP growth in one of two ways -- either in absolute terms (\\$50,000 to \\$50,100 -> \\$100 difference), or in relative terms (\\$50,000 to \\$100,000 -> 100% growth).  Do you see anything interesting if you use each of these approaches?~

# %% [markdown]
# # Solutions for Activities Below -- Don't look until you've tried first :)

# %% [markdown]
# ## Task 1: Life Expectancy Loss

# %%
# pivot the original table so that we can more readily analyse life expectancy values
le = df.pivot(index="country", columns="year", values="lifeExp")

le_loss = le[le[1952] > le[2007]]
le_loss
# Out:
# year         1952    1957    1962    1967    1972    1977    1982    1987  \
# country
# Swaziland  41.407  43.424  44.992  46.633  49.552  52.537  55.561  57.678
# Zimbabwe   48.451  50.469  52.358  53.995  55.635  57.674  60.363  62.351
#
# year         1992    1997    2002    2007
# country
# Swaziland  58.474  54.289  43.869  39.613
# Zimbabwe   60.377  46.809  39.989  43.487

# %% [markdown]
# ## Task 2: GDP Growth

# %%
# calculate the differences
gdp["changeReal"] = gdp[2007] - gdp[1952] # absolute growth
gdp["changePercent"] = 100*gdp[2007] / gdp[1952] # relative growth
gdp # take a quick look to make sure it seemed to about work
# Out:
# year                       1952         1957         1962         1967  \
# country
# Afghanistan          779.445314   820.853030   853.100710   836.197138
# Albania             1601.056136  1942.284244  2312.888958  2760.196931
# Algeria             2449.008185  3013.976023  2550.816880  3246.991771
# Angola              3520.610273  3827.940465  4269.276742  5522.776375
# Argentina           5911.315053  6856.856212  7133.166023  8052.953021
# ...                         ...          ...          ...          ...
# Vietnam              605.066492   676.285448   772.049160   637.123289
# West Bank and Gaza  1515.592329  1827.067742  2198.956312  2649.715007
# Yemen, Rep.          781.717576   804.830455   825.623201   862.442146
# Zambia              1147.388831  1311.956766  1452.725766  1777.077318
# Zimbabwe             406.884115   518.764268   527.272182   569.795071
#
# year                       1972          1977         1982         1987  \
# country
# ...

# %%
# first, look at the largest absolute change
gdp.sort_values(by=["changeReal"], ascending=False)[["changeReal", "changePercent"]]
# Out:
# year                changeReal  changePercent
# country
# Singapore         44828.041413    2036.300861
# Norway            39261.768450     488.906670
# Hong Kong, China  36670.557461    1300.573037
# Ireland           35465.716022     780.687291
# Austria           29989.416208     588.659645
# ...                        ...            ...
# Madagascar         -398.241589      72.402054
# Congo, Dem. Rep.   -502.990467      35.558848
# Djibouti           -587.047908      78.009312
# Haiti              -638.729785      65.293346
# Kuwait           -61075.363120      43.648240
#
# [142 rows x 2 columns]

# %%
# first, look at the largest absolute change
gdp.sort_values(by=["changePercent"], ascending=False)[["changeReal", "changePercent"]]
# Out:
# year                        changeReal  changePercent
# country
# Equatorial Guinea         11778.446627    3235.541662
# Taiwan                    27511.328927    2379.413107
# Korea, Rep.               22317.547504    2265.507069
# Singapore                 44828.041413    2036.300861
# Botswana                  11718.610629    1476.649937
# ...                                ...            ...
# Liberia                    -161.065655      72.016468
# Central African Republic   -365.294176      65.902126
# Haiti                      -638.729785      65.293346
# Kuwait                   -61075.363120      43.648240
# Congo, Dem. Rep.           -502.990467      35.558848
#
# [142 rows x 2 columns]
